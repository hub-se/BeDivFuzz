# %%
import itertools
import os

import numpy as np
import pandas as pd

# %%
fuzzers = ['bedivfuzz', 'bedivfuzz-simple', 'bedivfuzz-structure', 'bedivfuzz-split', 'rlcheck', 'zest']
subjects = ['ant', 'bcel', 'chocopy', 'closure', 'maven', 'nashorn', 'pngj', 'rhino', 'tomcat']
num_trials = 30
timeout = 180

# %%
def coverage_trial_df(experiment_name: str, fuzzer: str, subject: str, trial: int):
    df = pd.read_csv(
        os.path.join('results', experiment_name, fuzzer, subject, f'trial-{trial}', 'plot_data'),
        skipinitialspace=True
    )

    if fuzzer == 'bedivfuzz-split':
        zest_plot_data = pd.read_csv(
            os.path.join('results', experiment_name , fuzzer, subject, f'trial-{trial}', 'zest-results', 'plot_data'),
            skipinitialspace=True
        )

        df = pd.concat([zest_plot_data, df], ignore_index=True)

    # one datapoint per minute
    df = df.loc[np.linspace(0, len(df)-1, timeout, endpoint=True, dtype=np.int64)]
    df['time'] = range(1, timeout+1)
    df['trial'] = trial
    df['fuzzer'] = fuzzer
    df['subject'] = subject
    df['validity_rate'] = df['valid_inputs'] / (df['valid_inputs'] + df['invalid_inputs'])
    df['diverse_validity'] = df['valid_inputs'] / (df['valid_inputs'] + df['invalid_inputs'])

    if 'unique_valid_paths' in df.columns:
        return df[[
            'fuzzer', 'subject', 'trial', 'time', 
            'valid_inputs', 'invalid_inputs', 'validity_rate', 'unique_paths', 'unique_valid_paths',
            'num_coverage_probes', 'num_semantic_probes', 'b0', 'b1', 'b2'
        ]]

    else:
        return df[[
                'fuzzer', 'subject', 'trial', 'time', 
                'valid_inputs', 'invalid_inputs', 'validity_rate', 'unique_paths',
                'num_coverage_probes', 'num_semantic_probes', 'b0', 'b1', 'b2'
            ]]

# %%
def coverage_results_to_csv(experiment_name):
    dfs = []
    for f, s, t in itertools.product(fuzzers, subjects, range(1, num_trials+1)):
        if os.path.isdir(os.path.join('results', experiment_name, f, s, f"trial-{t}")):
            dfs.append(coverage_trial_df(experiment_name, fuzzer=f, subject=s, trial=t))
        else:
            print(f"Skipping trial: {f}-{s}-{t}")
    trials = pd.concat(dfs)

    trials.to_csv(
        os.path.join('results', experiment_name, 'coverage-data.csv'),
        index=False
    )
    return trials

# %%
eval_diversity_default = coverage_results_to_csv('eval-bedivfuzz-split/default')
eval_diversity_semantic = coverage_results_to_csv('eval-bedivfuzz-split/semantic')
# Out:
# Loading trial: bedivfuzz-ant-1
# Loading trial: bedivfuzz-ant-2
# Loading trial: bedivfuzz-ant-3
# Loading trial: bedivfuzz-ant-4
# Loading trial: bedivfuzz-ant-5
# Loading trial: bedivfuzz-ant-6
# Loading trial: bedivfuzz-ant-7
# Loading trial: bedivfuzz-ant-8
# Loading trial: bedivfuzz-ant-9
# Loading trial: bedivfuzz-ant-10
# Loading trial: bedivfuzz-ant-11
# Loading trial: bedivfuzz-ant-12
# Loading trial: bedivfuzz-ant-13
# Loading trial: bedivfuzz-ant-14
# Loading trial: bedivfuzz-ant-15
# Loading trial: bedivfuzz-ant-16
# Loading trial: bedivfuzz-chocopy-29
# Loading trial: bedivfuzz-chocopy-30
# Loading trial: bedivfuzz-closure-1
# Loading trial: bedivfuzz-closure-2
# Loading trial: bedivfuzz-closure-3
# Loading trial: bedivfuzz-closure-4
# Loading trial: bedivfuzz-closure-5
# Loading trial: bedivfuzz-closure-6
# Loading trial: bedivfuzz-closure-7
# Loading trial: bedivfuzz-closure-8
# Loading trial: bedivfuzz-closure-9
# Loading trial: bedivfuzz-closure-10
# Loading trial: bedivfuzz-closure-11
# Loading trial: bedivfuzz-closure-12
# Loading trial: bedivfuzz-closure-13
# Loading trial: bedivfuzz-closure-14
# Loading trial: bedivfuzz-closure-15
# Loading trial: bedivfuzz-closure-16
# Loading trial: bedivfuzz-closure-17
# Loading trial: bedivfuzz-closure-18
# Loading trial: bedivfuzz-closure-19
# Loading trial: bedivfuzz-closure-20
# Loading trial: bedivfuzz-closure-21
# Loading trial: bedivfuzz-closure-22
# Loading trial: bedivfuzz-closure-23
# Loading trial: bedivfuzz-closure-24
# Loading trial: bedivfuzz-closure-25
# Loading trial: bedivfuzz-closure-26
# Loading trial: bedivfuzz-closure-27
# Loading trial: bedivfuzz-closure-28
# Loading trial: bedivfuzz-closure-29
# Loading trial: bedivfuzz-closure-30
# Loading trial: bedivfuzz-maven-1
# Loading trial: bedivfuzz-maven-2
# Loading trial: bedivfuzz-maven-3
# Loading trial: bedivfuzz-maven-4
# Loading trial: bedivfuzz-maven-5
# Loading trial: bedivfuzz-maven-6
# Loading trial: bedivfuzz-maven-7
# Loading trial: bedivfuzz-maven-8
# Loading trial: bedivfuzz-maven-9
# Loading trial: bedivfuzz-maven-10
# Loading trial: bedivfuzz-maven-11
# Loading trial: bedivfuzz-maven-12
# Loading trial: bedivfuzz-maven-13
# Loading trial: bedivfuzz-maven-14
# Loading trial: bedivfuzz-maven-15
# Loading trial: bedivfuzz-maven-16
# Loading trial: bedivfuzz-maven-17
# Loading trial: bedivfuzz-maven-18
# Loading trial: bedivfuzz-maven-19
# Loading trial: bedivfuzz-maven-20
# Loading trial: bedivfuzz-maven-21
# Loading trial: bedivfuzz-maven-22
# Loading trial: bedivfuzz-maven-23
# Loading trial: bedivfuzz-maven-24
# Loading trial: bedivfuzz-maven-25
# Loading trial: bedivfuzz-maven-26
# Loading trial: bedivfuzz-maven-27
# Loading trial: bedivfuzz-maven-28
# Loading trial: bedivfuzz-maven-29
# Loading trial: bedivfuzz-maven-30
# Loading trial: bedivfuzz-pngj-1
# Loading trial: bedivfuzz-pngj-2
# Loading trial: bedivfuzz-pngj-3
# Loading trial: bedivfuzz-pngj-4
# Loading trial: bedivfuzz-pngj-5
# Loading trial: bedivfuzz-pngj-6
# Loading trial: bedivfuzz-pngj-7
# Loading trial: bedivfuzz-pngj-8
# Loading trial: bedivfuzz-pngj-9
# Loading trial: bedivfuzz-pngj-10
# Loading trial: bedivfuzz-pngj-11
# Loading trial: bedivfuzz-pngj-12
# Loading trial: bedivfuzz-pngj-13
# Loading trial: bedivfuzz-split-tomcat-18
# Loading trial: bedivfuzz-split-tomcat-19
# Loading trial: bedivfuzz-split-tomcat-20
# Loading trial: bedivfuzz-split-tomcat-21
# Loading trial: bedivfuzz-split-tomcat-22
# Loading trial: bedivfuzz-split-tomcat-23
# Loading trial: bedivfuzz-split-tomcat-24
# Loading trial: bedivfuzz-split-tomcat-25
# Loading trial: bedivfuzz-split-tomcat-26
# Loading trial: bedivfuzz-split-tomcat-27
# Loading trial: bedivfuzz-split-tomcat-28
# Loading trial: bedivfuzz-split-tomcat-29
# Loading trial: bedivfuzz-split-tomcat-30
# Loading trial: rlcheck-ant-1
# Loading trial: rlcheck-ant-2
# Loading trial: rlcheck-ant-3
# Loading trial: rlcheck-ant-4
# Loading trial: rlcheck-ant-5
# Loading trial: rlcheck-ant-6
# Loading trial: rlcheck-ant-7
# Loading trial: rlcheck-ant-8
# Loading trial: rlcheck-ant-9
# Loading trial: rlcheck-ant-10
# Loading trial: rlcheck-ant-11
# Loading trial: rlcheck-ant-12
# Loading trial: rlcheck-ant-13
# Loading trial: rlcheck-ant-14
# Loading trial: rlcheck-ant-15
# Loading trial: rlcheck-ant-16
# Loading trial: rlcheck-ant-17
# Loading trial: rlcheck-ant-18
# Loading trial: rlcheck-ant-19
# Loading trial: rlcheck-ant-20
# Loading trial: rlcheck-ant-21
# Loading trial: rlcheck-ant-22
# Loading trial: rlcheck-ant-23
# Loading trial: rlcheck-ant-24
# Loading trial: rlcheck-ant-25
# Loading trial: rlcheck-ant-26
# Loading trial: rlcheck-ant-27
# Loading trial: rlcheck-ant-28
# Loading trial: rlcheck-ant-29
# Loading trial: rlcheck-ant-30
# Skipping trial: rlcheck-bcel-1
# Skipping trial: rlcheck-bcel-2
# Skipping trial: rlcheck-bcel-3
# Skipping trial: rlcheck-bcel-4
# Skipping trial: rlcheck-bcel-5
# Skipping trial: rlcheck-bcel-6
# Skipping trial: rlcheck-bcel-7
# Skipping trial: rlcheck-bcel-8
# Skipping trial: rlcheck-bcel-9
# Skipping trial: rlcheck-bcel-10
# Skipping trial: rlcheck-bcel-11
# Skipping trial: rlcheck-bcel-12
# Skipping trial: rlcheck-bcel-13
# Skipping trial: rlcheck-bcel-14
# Skipping trial: rlcheck-bcel-15
# Skipping trial: rlcheck-bcel-16
# Skipping trial: rlcheck-bcel-17
# Skipping trial: rlcheck-bcel-18
# Skipping trial: rlcheck-bcel-19
# Skipping trial: rlcheck-bcel-20
# Skipping trial: rlcheck-bcel-21
# Skipping trial: rlcheck-bcel-22
# Skipping trial: rlcheck-bcel-23
# Skipping trial: rlcheck-bcel-24
# Skipping trial: rlcheck-bcel-25
# Skipping trial: rlcheck-bcel-26
# Skipping trial: rlcheck-bcel-27
# Skipping trial: rlcheck-bcel-28
# Skipping trial: rlcheck-bcel-29
# Skipping trial: rlcheck-bcel-30
# Skipping trial: rlcheck-chocopy-1
# Skipping trial: rlcheck-chocopy-2
# Skipping trial: rlcheck-chocopy-3
# Skipping trial: rlcheck-chocopy-4
# Skipping trial: rlcheck-chocopy-5
# Skipping trial: rlcheck-chocopy-6
# Skipping trial: rlcheck-chocopy-7
# Skipping trial: rlcheck-chocopy-8
# Skipping trial: rlcheck-chocopy-9
# Skipping trial: rlcheck-chocopy-10
# Skipping trial: rlcheck-chocopy-11
# Skipping trial: rlcheck-chocopy-12
# Skipping trial: rlcheck-chocopy-13
# Skipping trial: rlcheck-chocopy-14
# Skipping trial: rlcheck-chocopy-15
# Skipping trial: rlcheck-chocopy-16
# Skipping trial: rlcheck-chocopy-17
# Skipping trial: rlcheck-chocopy-18
# Skipping trial: rlcheck-chocopy-19
# Skipping trial: rlcheck-chocopy-20
# Skipping trial: rlcheck-chocopy-21
# Skipping trial: rlcheck-chocopy-22
# Skipping trial: rlcheck-chocopy-23
# Skipping trial: rlcheck-chocopy-24
# Skipping trial: rlcheck-chocopy-25
# Skipping trial: rlcheck-chocopy-26
# Skipping trial: rlcheck-chocopy-27
# Skipping trial: rlcheck-chocopy-28
# Skipping trial: rlcheck-chocopy-29
# Skipping trial: rlcheck-chocopy-30
# Loading trial: rlcheck-closure-1
# Loading trial: rlcheck-closure-2
# Loading trial: rlcheck-closure-3
# Loading trial: rlcheck-closure-4
# Loading trial: rlcheck-closure-5
# Loading trial: rlcheck-closure-6
# Loading trial: rlcheck-closure-7
# Loading trial: rlcheck-closure-8
# Loading trial: rlcheck-closure-9
# Loading trial: rlcheck-closure-10
# Loading trial: rlcheck-closure-11
# Loading trial: rlcheck-closure-12
# Loading trial: rlcheck-closure-13
# Loading trial: rlcheck-closure-14
# Loading trial: rlcheck-closure-15
# Loading trial: rlcheck-closure-16
# Loading trial: rlcheck-closure-17
# Loading trial: rlcheck-closure-18
# Loading trial: rlcheck-closure-19
# Loading trial: rlcheck-closure-20
# Loading trial: rlcheck-closure-21
# Loading trial: rlcheck-closure-22
# Loading trial: rlcheck-closure-23
# Loading trial: rlcheck-closure-24
# Loading trial: rlcheck-closure-25
# Loading trial: rlcheck-closure-26
# Loading trial: rlcheck-closure-27
# Loading trial: rlcheck-closure-28
# Loading trial: rlcheck-closure-29
# Loading trial: rlcheck-closure-30
# Loading trial: rlcheck-maven-1
# Loading trial: rlcheck-maven-2
# Loading trial: rlcheck-maven-3
# Loading trial: rlcheck-maven-4
# Loading trial: rlcheck-maven-5
# Loading trial: rlcheck-maven-6
# Loading trial: rlcheck-maven-7
# Loading trial: rlcheck-maven-8
# Loading trial: rlcheck-maven-9
# Loading trial: rlcheck-maven-10
# Loading trial: rlcheck-maven-11
# Loading trial: rlcheck-maven-12
# Loading trial: rlcheck-maven-13
# Loading trial: rlcheck-maven-14
# Loading trial: rlcheck-maven-15
# Loading trial: rlcheck-maven-16
# Loading trial: rlcheck-maven-17
# Loading trial: rlcheck-maven-18
# Loading trial: rlcheck-maven-19
# Loading trial: rlcheck-maven-20
# Loading trial: rlcheck-maven-21
# Loading trial: rlcheck-maven-22
# Loading trial: rlcheck-maven-23
# Loading trial: rlcheck-maven-24
# Loading trial: rlcheck-maven-25
# Loading trial: rlcheck-maven-26
# Loading trial: rlcheck-maven-27
# Loading trial: rlcheck-maven-28
# Loading trial: rlcheck-maven-29
# Loading trial: rlcheck-maven-30
# Skipping trial: rlcheck-pngj-1
# Skipping trial: rlcheck-pngj-2
# Skipping trial: rlcheck-pngj-3
# Skipping trial: rlcheck-pngj-4
# Skipping trial: rlcheck-pngj-5
# Skipping trial: rlcheck-pngj-6
# Skipping trial: rlcheck-pngj-7
# Skipping trial: rlcheck-pngj-8
# Skipping trial: rlcheck-pngj-9
# Skipping trial: rlcheck-pngj-10
# Skipping trial: rlcheck-pngj-11
# Skipping trial: rlcheck-pngj-12
# Skipping trial: rlcheck-pngj-13
# Skipping trial: rlcheck-pngj-14
# Skipping trial: rlcheck-pngj-15
# Skipping trial: rlcheck-pngj-16
# Skipping trial: rlcheck-pngj-17
# Skipping trial: rlcheck-pngj-18
# Skipping trial: rlcheck-pngj-19
# Skipping trial: rlcheck-pngj-20
# Skipping trial: rlcheck-pngj-21
# Skipping trial: rlcheck-pngj-22
# Skipping trial: rlcheck-pngj-23
# Skipping trial: rlcheck-pngj-24
# Skipping trial: rlcheck-pngj-25
# Skipping trial: rlcheck-pngj-26
# Skipping trial: rlcheck-pngj-27
# Skipping trial: rlcheck-pngj-28
# Skipping trial: rlcheck-pngj-29
# Skipping trial: rlcheck-pngj-30
# Loading trial: rlcheck-rhino-1
# Loading trial: rlcheck-rhino-2
# Loading trial: rlcheck-rhino-3
# Loading trial: rlcheck-rhino-4
# Loading trial: rlcheck-rhino-5
# Loading trial: rlcheck-rhino-6
# Loading trial: rlcheck-rhino-7
# Loading trial: rlcheck-rhino-8
# Loading trial: rlcheck-rhino-9
# Loading trial: rlcheck-rhino-10
# Loading trial: rlcheck-rhino-11
# Loading trial: rlcheck-rhino-12
# Loading trial: rlcheck-rhino-13
# Loading trial: rlcheck-rhino-14
# Loading trial: rlcheck-rhino-15
# Loading trial: rlcheck-rhino-16
# Loading trial: rlcheck-rhino-17
# Loading trial: rlcheck-rhino-18
# Loading trial: rlcheck-rhino-19
# Loading trial: rlcheck-rhino-20
# Loading trial: rlcheck-rhino-21
# Loading trial: rlcheck-rhino-22
# Loading trial: rlcheck-rhino-23
# Loading trial: rlcheck-rhino-24
# Loading trial: rlcheck-rhino-25
# Loading trial: rlcheck-rhino-26
# Loading trial: rlcheck-rhino-27
# Loading trial: rlcheck-rhino-28
# Loading trial: rlcheck-rhino-29
# Loading trial: rlcheck-rhino-30
# Loading trial: rlcheck-tomcat-1
# Loading trial: rlcheck-tomcat-2
# Loading trial: rlcheck-tomcat-3
# Loading trial: rlcheck-tomcat-4
# Loading trial: rlcheck-tomcat-5
# Loading trial: rlcheck-tomcat-6
# Loading trial: rlcheck-tomcat-7
# Loading trial: rlcheck-tomcat-8
# Loading trial: rlcheck-tomcat-9
# Loading trial: rlcheck-tomcat-10
# Loading trial: rlcheck-tomcat-11
# Loading trial: rlcheck-tomcat-12
# Loading trial: rlcheck-tomcat-13
# Loading trial: zest-chocopy-15
# Loading trial: zest-chocopy-16
# Loading trial: zest-chocopy-17
# Loading trial: zest-chocopy-18
# Loading trial: zest-chocopy-19
# Loading trial: zest-chocopy-20
# Loading trial: zest-chocopy-21
# ...
# Loading trial: bedivfuzz-split-rhino-28
# Loading trial: bedivfuzz-split-rhino-29
# Loading trial: bedivfuzz-split-rhino-30
# Loading trial: bedivfuzz-split-tomcat-1
# Loading trial: bedivfuzz-split-tomcat-2
# Loading trial: bedivfuzz-split-tomcat-3
# Loading trial: bedivfuzz-split-tomcat-4
# Loading trial: bedivfuzz-split-tomcat-5
# Loading trial: bedivfuzz-split-tomcat-6
# Loading trial: bedivfuzz-split-tomcat-7
# Loading trial: bedivfuzz-split-tomcat-8
# Loading trial: bedivfuzz-split-tomcat-9
# Loading trial: bedivfuzz-split-tomcat-10
# Loading trial: bedivfuzz-split-tomcat-11
# Loading trial: bedivfuzz-split-tomcat-12
# Loading trial: bedivfuzz-split-tomcat-13
# Loading trial: bedivfuzz-split-tomcat-14
# Loading trial: bedivfuzz-split-tomcat-15
# Loading trial: bedivfuzz-split-tomcat-16
# Loading trial: bedivfuzz-split-tomcat-17
# Loading trial: bedivfuzz-split-tomcat-18
# Loading trial: bedivfuzz-split-tomcat-19
# Loading trial: bedivfuzz-split-tomcat-20
# Loading trial: bedivfuzz-split-tomcat-21
# Loading trial: bedivfuzz-split-tomcat-22
# Loading trial: bedivfuzz-split-tomcat-23
# Loading trial: bedivfuzz-split-tomcat-24
# Loading trial: bedivfuzz-split-tomcat-25
# Loading trial: bedivfuzz-split-tomcat-26
# Loading trial: bedivfuzz-split-tomcat-27
# Loading trial: bedivfuzz-split-tomcat-28
# Loading trial: bedivfuzz-split-tomcat-29
# Loading trial: bedivfuzz-split-tomcat-30
# Loading trial: rlcheck-ant-1
# Loading trial: rlcheck-ant-2
# Loading trial: rlcheck-ant-3
# Loading trial: rlcheck-ant-4
# Loading trial: rlcheck-ant-5
# Loading trial: rlcheck-ant-6
# Loading trial: rlcheck-ant-7
# Loading trial: rlcheck-ant-8
# Loading trial: rlcheck-ant-9
# Loading trial: rlcheck-ant-10
# Loading trial: rlcheck-ant-11
# Loading trial: rlcheck-ant-12
# Loading trial: rlcheck-ant-13
# Loading trial: rlcheck-ant-14
# Loading trial: rlcheck-ant-15
# Loading trial: rlcheck-ant-16
# Loading trial: rlcheck-ant-17
# Loading trial: rlcheck-ant-18
# Loading trial: rlcheck-ant-19
# Loading trial: rlcheck-ant-20
# Loading trial: rlcheck-ant-21
# Loading trial: rlcheck-ant-22
# Loading trial: rlcheck-ant-23
# Loading trial: rlcheck-ant-24
# Loading trial: rlcheck-ant-25
# Loading trial: rlcheck-ant-26
# Loading trial: rlcheck-ant-27
# Loading trial: rlcheck-ant-28
# Loading trial: rlcheck-ant-29
# Loading trial: rlcheck-ant-30
# Skipping trial: rlcheck-bcel-1
# Skipping trial: rlcheck-bcel-2
# Skipping trial: rlcheck-bcel-3
# Skipping trial: rlcheck-bcel-4
# Skipping trial: rlcheck-bcel-5
# Skipping trial: rlcheck-bcel-6
# Skipping trial: rlcheck-bcel-7
# Skipping trial: rlcheck-bcel-8
# Skipping trial: rlcheck-bcel-9
# Skipping trial: rlcheck-bcel-10
# Skipping trial: rlcheck-bcel-11
# Skipping trial: rlcheck-bcel-12
# Skipping trial: rlcheck-bcel-13
# Skipping trial: rlcheck-bcel-14
# Skipping trial: rlcheck-bcel-15
# Skipping trial: rlcheck-bcel-16
# Skipping trial: rlcheck-bcel-17
# Skipping trial: rlcheck-bcel-18
# Skipping trial: rlcheck-bcel-19
# Skipping trial: rlcheck-bcel-20
# Skipping trial: rlcheck-bcel-21
# Skipping trial: rlcheck-bcel-22
# Skipping trial: rlcheck-bcel-23
# Skipping trial: rlcheck-bcel-24
# Skipping trial: rlcheck-bcel-25
# Skipping trial: rlcheck-bcel-26
# Skipping trial: rlcheck-bcel-27
# Skipping trial: rlcheck-bcel-28
# Skipping trial: rlcheck-bcel-29
# Skipping trial: rlcheck-bcel-30
# Skipping trial: rlcheck-chocopy-1
# Skipping trial: rlcheck-chocopy-2
# Skipping trial: rlcheck-chocopy-3
# Skipping trial: rlcheck-chocopy-4
# Skipping trial: rlcheck-chocopy-5
# Skipping trial: rlcheck-chocopy-6
# Skipping trial: rlcheck-chocopy-7
# Skipping trial: rlcheck-chocopy-8
# Skipping trial: rlcheck-chocopy-9
# Skipping trial: rlcheck-chocopy-10
# Skipping trial: rlcheck-chocopy-11
# Skipping trial: rlcheck-chocopy-12
# Skipping trial: rlcheck-chocopy-13
# Skipping trial: rlcheck-chocopy-14
# Skipping trial: rlcheck-chocopy-15
# Skipping trial: rlcheck-chocopy-16
# Skipping trial: rlcheck-chocopy-17
# Skipping trial: rlcheck-chocopy-18
# Skipping trial: rlcheck-chocopy-19
# Skipping trial: rlcheck-chocopy-20
# Skipping trial: rlcheck-chocopy-21
# Skipping trial: rlcheck-chocopy-22
# Skipping trial: rlcheck-chocopy-23
# Skipping trial: rlcheck-chocopy-24
# Skipping trial: rlcheck-chocopy-25
# Skipping trial: rlcheck-chocopy-26
# Skipping trial: rlcheck-chocopy-27
# Skipping trial: rlcheck-chocopy-28
# Skipping trial: rlcheck-chocopy-29
# Skipping trial: rlcheck-chocopy-30
# Loading trial: rlcheck-closure-1
# Loading trial: rlcheck-closure-2
# Loading trial: rlcheck-closure-3
# Loading trial: rlcheck-closure-4
# Loading trial: rlcheck-closure-5
# Loading trial: rlcheck-closure-6
# Loading trial: rlcheck-closure-7
# Loading trial: rlcheck-closure-8
# Loading trial: rlcheck-closure-9
# Loading trial: rlcheck-closure-10
# Loading trial: rlcheck-closure-11
# Loading trial: rlcheck-closure-12
# Loading trial: rlcheck-closure-13
# Loading trial: rlcheck-closure-14
# Loading trial: rlcheck-closure-15
# Loading trial: rlcheck-closure-16
# Loading trial: rlcheck-closure-17
# Loading trial: rlcheck-closure-18
# Loading trial: rlcheck-closure-19
# Loading trial: rlcheck-closure-20
# Loading trial: rlcheck-closure-21
# Loading trial: rlcheck-closure-22
# Loading trial: rlcheck-closure-23
# Loading trial: rlcheck-closure-24
# Loading trial: rlcheck-closure-25
# Loading trial: rlcheck-closure-26
# Loading trial: rlcheck-closure-27
# Loading trial: rlcheck-closure-28
# Loading trial: rlcheck-closure-29
# Loading trial: rlcheck-closure-30
# Loading trial: rlcheck-maven-1
# Loading trial: rlcheck-maven-2
# Loading trial: rlcheck-maven-3
# Loading trial: rlcheck-maven-4
# Loading trial: rlcheck-maven-5
# Loading trial: rlcheck-maven-6
# Loading trial: rlcheck-maven-7
# Loading trial: rlcheck-maven-8
# Loading trial: rlcheck-maven-9
# Loading trial: rlcheck-maven-10
# Loading trial: rlcheck-maven-11
# Loading trial: rlcheck-maven-12
# Loading trial: rlcheck-maven-13
# Loading trial: rlcheck-maven-14
# Loading trial: rlcheck-maven-15
# Loading trial: rlcheck-maven-16
# Loading trial: rlcheck-maven-17
# Loading trial: rlcheck-maven-18
# Loading trial: rlcheck-maven-19
# Loading trial: rlcheck-maven-20
# Loading trial: rlcheck-maven-21
# Loading trial: rlcheck-maven-22
# Loading trial: rlcheck-maven-23
# Loading trial: rlcheck-maven-24
# Loading trial: rlcheck-maven-25
# Loading trial: rlcheck-maven-26
# Loading trial: rlcheck-maven-27
# Loading trial: rlcheck-maven-28
# Loading trial: rlcheck-maven-29
# Loading trial: rlcheck-maven-30
# Skipping trial: rlcheck-pngj-1
# Skipping trial: rlcheck-pngj-2
# Skipping trial: rlcheck-pngj-3
# Skipping trial: rlcheck-pngj-4
# Skipping trial: rlcheck-pngj-5
# Skipping trial: rlcheck-pngj-6
# Skipping trial: rlcheck-pngj-7
# Skipping trial: rlcheck-pngj-8
# Skipping trial: rlcheck-pngj-9
# Skipping trial: rlcheck-pngj-10
# Skipping trial: rlcheck-pngj-11
# Skipping trial: rlcheck-pngj-12
# Skipping trial: rlcheck-pngj-13
# Skipping trial: rlcheck-pngj-14
# Skipping trial: rlcheck-pngj-15
# Skipping trial: rlcheck-pngj-16
# Skipping trial: rlcheck-pngj-17
# Skipping trial: rlcheck-pngj-18
# Skipping trial: rlcheck-pngj-19
# Skipping trial: rlcheck-pngj-20
# Skipping trial: rlcheck-pngj-21
# Skipping trial: rlcheck-pngj-22
# Skipping trial: rlcheck-pngj-23
# Skipping trial: rlcheck-pngj-24
# Skipping trial: rlcheck-pngj-25
# Skipping trial: rlcheck-pngj-26
# Skipping trial: rlcheck-pngj-27
# Skipping trial: rlcheck-pngj-28
# Skipping trial: rlcheck-pngj-29
# Skipping trial: rlcheck-pngj-30
# Loading trial: rlcheck-rhino-1
# Loading trial: rlcheck-rhino-2
# Loading trial: rlcheck-rhino-3
# Loading trial: rlcheck-rhino-4
# Loading trial: rlcheck-rhino-5
# Loading trial: rlcheck-rhino-6
# Loading trial: rlcheck-rhino-7
# Loading trial: rlcheck-rhino-8
# Loading trial: rlcheck-rhino-9
# Loading trial: rlcheck-rhino-10
# Loading trial: rlcheck-rhino-11
# Loading trial: rlcheck-rhino-12
# Loading trial: rlcheck-rhino-13
# Loading trial: rlcheck-rhino-14
# Loading trial: rlcheck-rhino-15
# Loading trial: rlcheck-rhino-16
# Loading trial: rlcheck-rhino-17
# Loading trial: rlcheck-rhino-18
# Loading trial: rlcheck-rhino-19
# Loading trial: rlcheck-rhino-20
# Loading trial: rlcheck-rhino-21
# Loading trial: rlcheck-rhino-22
# Loading trial: rlcheck-rhino-23
# Loading trial: rlcheck-rhino-24
# Loading trial: rlcheck-rhino-25
# Loading trial: rlcheck-rhino-26
# Loading trial: rlcheck-rhino-27
# Loading trial: rlcheck-rhino-28
# Loading trial: rlcheck-rhino-29
# Loading trial: rlcheck-rhino-30
# Loading trial: rlcheck-tomcat-1
# Loading trial: rlcheck-tomcat-2
# Loading trial: rlcheck-tomcat-3
# Loading trial: rlcheck-tomcat-4
# Loading trial: rlcheck-tomcat-5
# Loading trial: rlcheck-tomcat-6
# Loading trial: rlcheck-tomcat-7
# Loading trial: rlcheck-tomcat-8
# Loading trial: rlcheck-tomcat-9
# Loading trial: rlcheck-tomcat-10
# Loading trial: rlcheck-tomcat-11
# Loading trial: rlcheck-tomcat-12
# Loading trial: rlcheck-tomcat-13
# Loading trial: rlcheck-tomcat-14
# Loading trial: rlcheck-tomcat-15
# Loading trial: rlcheck-tomcat-16
# Loading trial: rlcheck-tomcat-17
# Loading trial: rlcheck-tomcat-18
# Loading trial: rlcheck-tomcat-19
# Loading trial: rlcheck-tomcat-20
# Loading trial: rlcheck-tomcat-21
# Loading trial: rlcheck-tomcat-22
# Loading trial: rlcheck-tomcat-23
# Loading trial: rlcheck-tomcat-24
# Loading trial: rlcheck-tomcat-25
# Loading trial: rlcheck-tomcat-26
# Loading trial: rlcheck-tomcat-27
# Loading trial: rlcheck-tomcat-28
# Loading trial: rlcheck-tomcat-29
# Loading trial: rlcheck-tomcat-30
# Loading trial: zest-ant-1
# Loading trial: zest-ant-2
# Loading trial: zest-ant-3
# Loading trial: zest-ant-4
# Loading trial: zest-ant-5
# Loading trial: zest-ant-6
# Loading trial: zest-ant-7
# Loading trial: zest-ant-8
# Loading trial: zest-ant-9
# Loading trial: zest-ant-10
# Loading trial: zest-ant-11
# Loading trial: zest-ant-12
# Loading trial: zest-ant-13
# Loading trial: zest-ant-14
# Loading trial: zest-ant-15
# Loading trial: zest-ant-16
# Loading trial: zest-ant-17
# Loading trial: zest-ant-18
# Loading trial: zest-ant-19
# Loading trial: zest-ant-20
# Loading trial: zest-ant-21
# Loading trial: zest-ant-22
# Loading trial: zest-ant-23
# Loading trial: zest-ant-24
# Loading trial: zest-ant-25
# Loading trial: zest-ant-26
# Loading trial: zest-ant-27
# Loading trial: zest-ant-28
# Loading trial: zest-ant-29
# Loading trial: zest-ant-30
# Loading trial: zest-bcel-1
# Loading trial: zest-bcel-2
# Loading trial: zest-bcel-3
# Loading trial: zest-bcel-4
# Loading trial: zest-bcel-5
# Loading trial: zest-bcel-6
# Loading trial: zest-bcel-7
# Loading trial: zest-bcel-8
# Loading trial: zest-maven-15
# Loading trial: zest-maven-16
# Loading trial: zest-maven-17
# Loading trial: zest-maven-18
# Loading trial: zest-maven-19
# Loading trial: zest-maven-20
# Loading trial: zest-maven-21
# Loading trial: zest-maven-22
# Loading trial: zest-maven-23
# Loading trial: zest-maven-24
# Loading trial: zest-maven-25
# Loading trial: zest-maven-26
# Loading trial: zest-maven-27
# Loading trial: zest-maven-28
# Loading trial: zest-maven-29
# Loading trial: zest-maven-30
# Loading trial: zest-pngj-1
# Loading trial: zest-pngj-2
# Loading trial: zest-pngj-3
# Loading trial: zest-pngj-4
# Loading trial: zest-pngj-5
# Loading trial: zest-pngj-6
# Loading trial: zest-pngj-7
# Loading trial: zest-pngj-8
# Loading trial: zest-pngj-9
# Loading trial: zest-pngj-10
# Loading trial: zest-pngj-11
# Loading trial: zest-pngj-12
# Loading trial: zest-pngj-13
# Loading trial: zest-pngj-14
# Loading trial: zest-pngj-15
# Loading trial: zest-pngj-16
# Loading trial: zest-pngj-17
# Loading trial: zest-pngj-18
# Loading trial: zest-pngj-19
# Loading trial: zest-pngj-20
# Loading trial: zest-pngj-21
# Loading trial: zest-pngj-22
# Loading trial: zest-pngj-23
# Loading trial: zest-pngj-24
# Loading trial: zest-pngj-25
# Loading trial: zest-pngj-26
# Loading trial: zest-pngj-27
# Loading trial: zest-pngj-28
# Loading trial: zest-pngj-29
# Loading trial: zest-pngj-30
# Loading trial: zest-rhino-1
# Loading trial: zest-rhino-2
# Loading trial: zest-rhino-3
# Loading trial: zest-rhino-4
# Loading trial: zest-rhino-5
# Loading trial: zest-rhino-6
# Loading trial: zest-rhino-7
# Loading trial: zest-rhino-8
# Loading trial: zest-rhino-9
# Loading trial: zest-rhino-10
# Loading trial: zest-rhino-11
# Loading trial: zest-rhino-12
# Loading trial: zest-rhino-13
# Loading trial: zest-rhino-14
# Loading trial: zest-rhino-15
# Loading trial: zest-rhino-16
# Loading trial: zest-rhino-17
# Loading trial: zest-rhino-18
# Loading trial: zest-rhino-19
# Loading trial: zest-rhino-20
# Loading trial: zest-rhino-21
# Loading trial: zest-rhino-22
# Loading trial: zest-rhino-23
# Loading trial: zest-rhino-24
# Loading trial: zest-rhino-25
# Loading trial: zest-rhino-26
# Loading trial: zest-rhino-27
# Loading trial: zest-rhino-28
# Loading trial: zest-rhino-29
# Loading trial: zest-rhino-30
# Loading trial: zest-tomcat-1
# Loading trial: zest-tomcat-2
# Loading trial: zest-tomcat-3
# Loading trial: zest-tomcat-4
# Loading trial: zest-tomcat-5
# Loading trial: zest-tomcat-6
# Loading trial: zest-tomcat-7
# Loading trial: zest-tomcat-8
# Loading trial: zest-tomcat-9
# Loading trial: zest-tomcat-10
# Loading trial: zest-tomcat-11
# Loading trial: zest-tomcat-12
# Loading trial: zest-tomcat-13
# Loading trial: zest-tomcat-14
# Loading trial: zest-tomcat-15
# Loading trial: zest-tomcat-16
# Loading trial: zest-tomcat-17
# Loading trial: zest-tomcat-18
# Loading trial: zest-tomcat-19
# Loading trial: zest-tomcat-20
# Loading trial: zest-tomcat-21
# Loading trial: zest-tomcat-22
# Loading trial: zest-tomcat-23
# Loading trial: zest-tomcat-24
# Loading trial: zest-tomcat-25
# Loading trial: zest-tomcat-26
# Loading trial: zest-tomcat-27
# Loading trial: zest-tomcat-28
# Loading trial: zest-tomcat-29
# Loading trial: zest-tomcat-30

# %%
crash_to_id = {}
def deduplicate_crash(exception_class, stack_trace):
    key = (exception_class, '-'.join(str(stack_trace).split('-')[:3]))
    if str(exception_class) == 'nan':
        return -1
    if key in crash_to_id.keys():
        return crash_to_id[key]
    else:
        crash_id = len(crash_to_id)
        crash_to_id[key] = crash_id
        return crash_id

# %%
def crash_trial_df(experiment_name: str, fuzzer: str, subject: str, trial: int):
    # Read failure stats
    df = pd.read_csv(
        os.path.join('results', experiment_name, fuzzer, subject, f"trial-{trial}", 'failure_info.csv'),
        skipinitialspace=True
    )

    # Map TTE to failure messages
    fuzz_log = os.path.join('results', experiment_name, fuzzer, subject, f"trial-{trial}", 'fuzz.log')
    tte_to_message = {}
    if os.path.exists(fuzz_log):
        with open(fuzz_log, 'r') as f:
            for line in f:
                if 'Found failure' not in line:
                    continue
                tokens = line.split(" ")
                tte = tokens[0]
                #crash_class = tokens[6]
                message = " ".join(tokens[7:])
                tte_to_message[tte] = message

    df['fuzzer'] = fuzzer
    df['subject'] = subject
    df['trial'] = trial
    df['tte'] = df['# ttd']
    if not df.empty: # Assignment fails if df is empty
        df['exception_class'] = df.apply(lambda row: str(row['exception_class']).split("class ")[1], axis=1)
    df['crash_id'] = df.apply(lambda row: deduplicate_crash(row['exception_class'], row['top5_stack_trace']), axis=1)
    df['location'] = df.apply(lambda row: ''.join(str(row['top5_stack_trace']).split('-')[:1]), axis=1)
    df['message'] = df.apply(lambda row: tte_to_message.get(str(row['# ttd']), 'no message'), axis=1)
    df['stack_trace'] = df['top5_stack_trace']

    return df[['fuzzer', 'subject', 'trial', 'tte', 'exception_class', 'location', 'message', 'stack_trace', 'crash_id']]

# %%
def crash_results_to_csv(experiment_name: str):
    trial_crashes = []
    for f, s, t in itertools.product(fuzzers, subjects, range(1, num_trials+1)):
        if os.path.isdir(os.path.join('results', experiment_name, f, s, f"trial-{t}")):
            trial_crashes.append(crash_trial_df(experiment_name, fuzzer=f, subject=s, trial=t))
    crash_data = pd.concat(trial_crashes)
    crash_data.to_csv(
        os.path.join('results', experiment_name, 'crash-data.csv'),
        index=False
    )
    return crash_data

# %%
thesis_default = crash_results_to_csv('eval-bedivfuzz-split-thesis-default')
metrics_default = crash_results_to_csv('eval-bedivfuzz-metrics-default')

thesis_semantic = crash_results_to_csv('eval-bedivfuzz-split-thesis-semantic')
metrics_semantic = crash_results_to_csv('eval-bedivfuzz-metrics-semantic')

# %% [markdown]
# # Process ICSE22 Results

# %%
import shutil

# %%
# Reorganizes the directory structure of the original artifact
move_dirs = False
experiment = 'eval-icse22-crashes'

if move_dirs:
    base_dir = os.path.join('results', experiment, 'java-data')
    for d in os.listdir(base_dir):
        results_dir = os.path.join(base_dir, d)
        if os.path.isdir(results_dir):
            tokens = d.split('-')
            tech = tokens[0]
            if tokens[1] in ['simple', 'structure']:
                tech = f"{tokens[0]}-{tokens[1]}"
                benchmark = tokens[2]
                trial_id = f"trial-{'-'.join(tokens[3:])}"
            else:
                benchmark = tokens[1]
                trial_id = f"trial-{'-'.join(tokens[2:])}" 
    
            new_results_dir = os.path.join('results', experiment, tech)
            if not os.path.exists(new_results_dir):
                os.makedirs(new_results_dir)
    
            shutil.move(results_dir, os.path.join(new_results_dir, benchmark, trial_id))

# %%
fuzzers = ['bediv-simple', 'bediv-structure', 'quickcheck', 'rl', 'zest']
subjects = ['ant', 'closure', 'maven', 'nashorn', 'rhino', 'tomcat']
num_trials = 30
timeout = 60

# %%
def icse_coverage_trial_df(fuzzer: str, subject: str, trial: int):
    if fuzzer in ['quickcheck', 'rl']:
        plot_data = os.path.join('results', 'eval-icse22-coverage', fuzzer, subject, f'trial-{trial}-replay', 'plot_data')
    else:
        plot_data = os.path.join('results', 'eval-icse22-coverage', fuzzer, subject, f'trial-{trial}', 'plot_data')

    df = pd.read_csv(
        plot_data,
        names=[
            'unix_time', 'unique_crashes', 'total_cov', 'valid_cov', 'total_inputs', 'valid_inputs', 
            'unique_valid_paths', 'unique_valid_branch_sets', 'unique_valid_inputs', 'b0', 'b1', 'b2'],
        header=None,
        skiprows=1,
        skipinitialspace=True
    )

    # two datapoints per minute
    df = df.loc[np.linspace(0, len(df)-1, 2*timeout, endpoint=True, dtype=np.int64)]
    df['time'] = np.arange(0.5, timeout + 0.5, 0.5)
    df['trial'] = trial
    df['fuzzer'] = fuzzer
    df['subject'] = subject
    df['validity_rate'] = df['valid_inputs'] / df['total_inputs']

    return df[[
            'fuzzer', 'subject', 'trial', 'time', 
            'valid_inputs', 'total_inputs', 'validity_rate', 'unique_valid_paths', 'b0', 'b1', 'b2'
        ]]

# %%
dfs = []
for f, s, t in itertools.product(fuzzers, subjects, range(1, num_trials+1)):
    dfs.append(icse_coverage_trial_df(fuzzer=f, subject=s, trial=t))
    
trials = pd.concat(dfs)
trials.to_csv(
    os.path.join('results', 'eval-icse22-coverage', 'coverage-data.csv'),
    index=False
)

# %%
def icse_crash_trial_df(fuzzer: str, subject: str, trial: int):
    def get_num_failures(failure_directory):
        num_files = len([entry for entry in os.listdir(failure_directory) if os.path.isfile(os.path.join(failure_directory, entry))])
        assert num_files % 2 == 0, failure_directory
        return int(num_files / 2) # two files per failure
    
    def read_stack_trace(file):
        with open(file, 'r') as f:
            return '-'.join([line.strip() for line in f][1:]) # skip exception class

    def read_crash_stats(file):
        with open(file, 'r') as f:
            lines = [line.strip() for line in f]
            clazz = (lines[0].split("class "))[1]
            tte = (lines[1].split("TTD: "))[1]
            return clazz, int(int(tte) / 1000) # convert ms to s

    # Map failure_id to failure message
    failure_directory = os.path.join('results', 'eval-icse22-crashes', fuzzer, subject, f"trial-{trial}", 'failure_info')
    fuzz_log = os.path.join('results', 'eval-icse22-crashes', fuzzer, subject, f"trial-{trial}", 'fuzz.log')
    failure_id_to_message = {}

    # Return empty df if no crashes have been found
    if not os.path.exists(fuzz_log):
        return pd.DataFrame(columns=['fuzzer', 'subject', 'trial', 'tte', 'exception_class', 'location', 'message', 'stack_trace', 'crash_id'])
    
    rows = []
    with open(fuzz_log, 'r') as f:
        for line in f:
            if 'Found crash' not in line:
                continue
            tokens = line.split(" ")
            tte = int(int(tokens[0]) / 1000) # convert ms to s
            failure_id = tokens[1]
            exception_class = tokens[5]
            message = " ".join(tokens[7:]) if len(tokens) > 7 else 'no message'
            stack_trace_file = os.path.join(failure_directory, f"{failure_id}.stacktrace")
            stack_trace = read_stack_trace(stack_trace_file)

            rows.append({
                    'fuzzer': fuzzer,
                    'subject': subject,
                    'trial': trial,
                    'tte': tte,
                    'exception_class': exception_class,
                    'location': stack_trace.split('-')[0],
                    'message': message,
                    'stack_trace': stack_trace,
                    'crash_id': deduplicate_icse_crash(exception_class, stack_trace.split('-')[0])
                })

    return pd.DataFrame(rows)

# %%
# Note: this takes *a lot* of time (because quickcheck produces so many crashes)
# Set the following flag to true if you have some spare time...
generate_icse_crash_data = False

icse_crash_to_id = {}
def deduplicate_icse_crash(exception_class, location):
    key = (exception_class, location)
    if key in icse_crash_to_id.keys():
        return icse_crash_to_id[key]
    else:
        crash_id = len(icse_crash_to_id)
        icse_crash_to_id[key] = crash_id
        return crash_id

# Generate ICSE crash data csv
if generate_icse_crash_data:
    trial_crashes = []
    for f, s, t in itertools.product(fuzzers, subjects, range(1, num_trials+1)):
        trial_crashes.append(icse_crash_trial_df(fuzzer=f, subject=s, trial=t))
        
    crash_data = pd.concat(trial_crashes)
    crash_data.to_csv(
        os.path.join('results', 'eval-icse22-crashes', 'crash-data.csv'),
        index=False
    )

# %%
icse_crash_to_id
# Out:
# {('java.lang.RuntimeException',
#   'com.google.javascript.jscomp.jarjar.com.google.common.base.Preconditions.checkArgument(Preconditions.java)'): 0,
#  ('java.lang.StringIndexOutOfBoundsException',
#   'java.base/java.lang.StringLatin1.charAt(StringLatin1.java:47)'): 1,
#  ('java.lang.RuntimeException',
#   'com.google.javascript.jscomp.InlineObjectLiterals$InliningBehavior.afterExitScope(InlineObjectLiterals.java)'): 2,
#  ('java.lang.RuntimeException', ''): 3,
#  ('java.lang.NullPointerException',
#   'com.google.javascript.jscomp.jarjar.com.google.common.base.Preconditions.checkNotNull(Preconditions.java)'): 4,
#  ('java.lang.RuntimeException',
#   'com.google.javascript.jscomp.VarCheck.handleUndeclaredVariableRef(VarCheck.java)'): 5,
#  ('java.lang.RuntimeException',
#   'com.google.javascript.jscomp.PeepholeRemoveDeadCode.tryFoldLabel(PeepholeRemoveDeadCode.java)'): 6,
#  ('java.lang.AssertionError',
#   'jdk.scripting.nashorn/jdk.nashorn.internal.parser.ParserContext.pop(ParserContext.java:91)'): 7,
#  ('java.lang.IllegalStateException',
#   'org.mozilla.javascript.Kit.codeBug(Kit.java)'): 8,
#  ('java.lang.NullPointerException',
#   'org.mozilla.javascript.optimizer.BodyCodegen.visitObjectLiteral(BodyCodegen.java)'): 9,
#  ('java.lang.NullPointerException', ''): 10,
#  ('java.lang.ClassCastException',
#   'org.mozilla.javascript.Parser.destructuringAssignmentHelper(Parser.java)'): 11,
#  ('java.lang.VerifyError',
#   'java.base/java.lang.Class.getDeclaredConstructors0(Native Method)'): 12,
#  ('java.lang.ClassCastException', ''): 13,
#  ('java.lang.NullPointerException',
#   'com.google.javascript.jscomp.jarjar.com.google.common.base.Preconditions.checkNotNull(Preconditions.java:897)'): 14,
#  ('java.lang.RuntimeException',
#   'com.google.javascript.jscomp.jarjar.com.google.common.base.Preconditions.checkArgument(Preconditions.java:301)'): 15,
#  ('java.lang.RuntimeException',
#   'com.google.javascript.jscomp.InlineObjectLiterals$InliningBehavior.afterExitScope(InlineObjectLiterals.java:87)'): 16,
#  ('java.lang.RuntimeException',
#   'com.google.javascript.jscomp.VarCheck.handleUndeclaredVariableRef(VarCheck.java:291)'): 17,
#  ('java.lang.IllegalStateException',
#   'org.mozilla.javascript.Kit.codeBug(Kit.java:391)'): 18,
#  ('java.lang.NullPointerException',
#   'org.mozilla.javascript.optimizer.BodyCodegen.visitObjectLiteral(BodyCodegen.java:2076)'): 19,
#  ('java.lang.ClassCastException',
#   'org.mozilla.javascript.Parser.destructuringAssignmentHelper(Parser.java:4028)'): 20,
#  ('java.lang.ClassCastException',
#   'org.mozilla.javascript.Parser.destructuringAssignmentHelper(Parser.java:4033)'): 21,
#  ('java.lang.IllegalStateException',
#   'org.mozilla.javascript.Kit.codeBug(Kit.java:375)'): 22,
#  ('java.lang.OutOfMemoryError',
#   'org.apache.tomcat.util.digester.RulesBase.add(RulesBase.java:108)'): 23,
#  ('java.lang.OutOfMemoryError',
#   'java.xml/com.sun.org.apache.xerces.internal.impl.XMLDocumentFragmentScannerImpl$ElementStack2.<init>(XMLDocumentFragmentScannerImpl.java:2053)'): 24,
#  ('java.lang.OutOfMemoryError',
#   'java.xml/com.sun.org.apache.xerces.internal.util.NamespaceSupport.<init>(NamespaceSupport.java:71)'): 25,
#  ('java.lang.OutOfMemoryError',
#   'java.base/java.util.Arrays$ArrayList.toArray(Arrays.java:4333)'): 26,
#  ('java.lang.OutOfMemoryError',
#   'java.base/java.util.HashMap.newNode(HashMap.java:1815)'): 27,
#  ('java.lang.OutOfMemoryError',
#   'org.apache.tomcat.util.digester.Digester.addCallParam(Digester.java:1555)'): 28,
#  ('java.lang.OutOfMemoryError',
#   'jdk.internal.reflect.GeneratedMethodAccessor1.invoke(Unknown Source)'): 29,
#  ('java.lang.OutOfMemoryError',
#   'java.xml/com.sun.org.apache.xerces.internal.impl.XMLDocumentFragmentScannerImpl.<init>(XMLDocumentFragmentScannerImpl.java:412)'): 30,
#  ('java.lang.OutOfMemoryError', ''): 31,
#  ('java.lang.ArrayIndexOutOfBoundsException',
#   'org.mozilla.javascript.TokenStream.ungetChar(TokenStream.java)'): 32}
